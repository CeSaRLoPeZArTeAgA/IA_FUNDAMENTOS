# %%
def P(dE,T):
    if dE < 0:
        return 1
    else:
        return math.exp(-dE/T)

# %%
import math
E_0=50
E_new=65
T=[100,20,2]
Rand=[0.35, 0.35, 0.35]
dE=[15.00,15.00,15.00]

dE_a=0.0
for i in range(3):
    dE_a=dE[i]+dE_a
    print(P(dE_a,T[i]))
# Out:
# 0.8607079764250578
# 0.22313016014842982
# 1.6918979226151304e-10
